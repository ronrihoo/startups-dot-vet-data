# %% [markdown]
# # StartUps.vet

# %% [markdown]
# ### Quick Introduction

# %% [markdown]
# The data was scraped from the startups.vet webpages. It needs some cleaning up before it can be comfortably analyzed.

# %% [markdown]
# ### Data

# %%
import pandas as pd

data = pd.read_csv('./startups_data.csv')

# %%
data
# Out:
#                                            Website  Employees Total Funding  \
# 0                                        AgentHero        NaN             k
# 1                                    Akouba Credit        NaN             k
# 2                                           Andela        NaN             k
# 3                                   AuditPad, Inc.        2.0             k
# 4   Avening Management and Technical Services, LLC        NaN             k
# 5                                   Base Directory        4.0  Bootstrapped
# 6                                     Base of Fire        NaN             k
# 7               Biao Skincare and Community Source        NaN             k
# 8                                      CauseEngine        NaN             k
# 9                                      CauseEngine        NaN             k
# 10                                   Combat2Career        NaN             k
# ...
