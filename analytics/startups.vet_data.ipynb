# %% [markdown]
# # StartUps.vet

# %% [markdown]
# ### Quick Introduction

# %% [markdown]
# The following data sets have been scraped from `startups.vet/companies` and from `vip.vetbiz.gov/Public/Search/Default.aspx`.
#
# Both data sets require some cleaning up before they can be comfortably analyzed.

# %% [markdown]
# ### Data

# %%
import pandas as pd

# %%
startups_data = pd.read_csv('../csv_files/startups_data.csv')

# %%
startups_data.head(5)
# Out:
#                                           Website  Employees Total Funding  \
# 0                                       AgentHero        NaN             k
# 1                                   Akouba Credit        NaN             k
# 2                                          Andela        NaN             k
# 3                                  AuditPad, Inc.        2.0             k
# 4  Avening Management and Technical Services, LLC        NaN             k
#
#   Stage  Year Founded Organization Affiliation  Total Founders  \
# 0   NaN          2015        Patriot Boot Camp             NaN
# 1   NaN          2015                   Bunker             NaN
# 2   NaN          2015        Patriot Boot Camp             NaN
# 3   NaN          2013        Patriot Boot Camp             2.0
# 4   NaN          2012        Patriot Boot Camp             1.0
#
#    Veteran Founders Veteran Executives
# 0               NaN               True
# 1               NaN               True
# 2               NaN               True
# 3               1.0               True
# 4               1.0               True

# %%
vetbiz_data = pd.read_csv('../csv_files/vetbiz_data.csv')

# %%
vetbiz_data.head(5)
# Out:
#         Duns                          BusinessName                    DbaName  \
# 0   78705297                       Eugene Robinson  Anadine Design Management
# 1  117941695            DL Stone Enterprises, LLC           Stone Enterprises
# 2  961566031                 Friendship SDVB , LLC                        NaN
# 3  791265882   International Mortuary Shipping LLC                        NaN
# 4  808852177                   (CMR) Services Inc.                        NaN
#
#            City State       Phone                 CompanyEmail  \
# 0       Buffalo    NY  7165636156          anadine51@yahoo.com
# 1  Garden Ridge    TX  2106960919   sales@stonespecialties.com
# 2        Austin    TX  4798761012  friendshipco@mindspring.com
# 3         Union    SC  8644660100            sprow@charter.net
# 4    Royse City    TX  3039013455       clayrankin79@gmail.com
#
#                              WebSite            LastVerified  \
# 0                                NaN   9/10/2015 12:00:00 AM
# 1               stonespecialties.com  12/23/2015 12:00:00 AM
# 2             friendshipcompany1.com  12/10/2015 12:00:00 AM
# 3  internationalmortuaryshipping.com   9/15/2016 12:00:00 AM
# 4                                NaN   5/18/2015 12:00:00 AM
#
#            ExpirationDate     ...       \
# 0   9/10/2017 12:00:00 AM     ...
# 1  12/23/2017 12:00:00 AM     ...
# 2  12/10/2017 12:00:00 AM     ...
# 3   9/15/2018 12:00:00 AM     ...
# 4   5/18/2017 12:00:00 AM     ...
#
#                                                Naics  \
# 0  236118, 236220, 237310, 238220, 238910, 238990...
# 1  313110, 314910, 315190, 315210, 315240, 316998...
# 2  236220, 311991, 325120, 423420, 423430, 423990...
# 3                                     812210, 812220
# 4                                     112111, 561611
#
#                                   Fsc         Psc  \
# 0                                 NaN         NaN
# 1  7320, 7340, 8105, 8405, 8410, 8520         NaN
# 2                                6830         NaN
# 3                                 NaN         NaN
# 4                                 NaN  AA95, AB10
#
#                              GeographicalServiceArea CommercialContracts  \
# 0                                                 NY                  No
# 1  AK, AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, HI...                 Yes
# 2                                                 XX                 Yes
# 3                                                 XX                  No
# 4                                             CO, TX                  No
#
#    DodContracts  FSS           LastModified MentorProtege JointVenture
# 0            No   No   8/25/2016 9:20:39 AM            No           No
# 1            No   No   2/6/2016 11:36:08 PM            No           No
# 2           Yes  Yes  12/10/2015 1:07:04 PM            No           No
# 3            No   No   9/15/2016 9:39:11 AM            No           No
# 4            No   No  7/20/2015 12:59:42 PM            No           No
#
# [5 rows x 41 columns]
